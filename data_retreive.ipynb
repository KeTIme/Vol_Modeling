# %%
#data extraction
import os, zipfile
dir_name = '..\data'
extension = ".zip"
os.chdir(dir_name) # change directory from working dir to dir with files
for item in os.listdir(dir_name): # loop through items in dir
    if item.endswith(extension): # check for ".zip" extension
        file_name = os.path.abspath(item) # get full path of files
        zip_ref = zipfile.ZipFile(file_name) # create zipfile object
        zip_ref.extractall(dir_name) # extract file to dir
        zip_ref.close() # close file
        os.remove(file_name) # delete zipped file

# %%
import pandas as pd

# %%
df = pd.read_csv('..\data\SkewMoneynessEOD_2016-01-04.csv')
df.head()
# Out:
#   underlying_symbol        date  underlying_price  period    strike  \
# 0              ^SPX  2016-01-04           2012.66      30   805.064
# 1              ^SPX  2016-01-04           2012.66      30   905.697
# 2              ^SPX  2016-01-04           2012.66      30  1006.330
# 3              ^SPX  2016-01-04           2012.66      30  1106.963
# 4              ^SPX  2016-01-04           2012.66      30  1207.596
#
#   option_type   delta  moneyness      iv
# 0           P -0.0005       60.0  1.0140
# 1           P -0.0008       55.0  0.9143
# 2           P -0.0011       50.0  0.8157
# 3           P -0.0016       45.0  0.7290
# 4           P -0.0025       40.0  0.6507

# %%
import glob
path = "../data/*.csv"
first = 1
for fname in glob.glob(path):
    first = 0
    if not first:
        tmp = pd.read_csv(fname)
        df = pd.concat([df,tmp])

# %%
df.to_csv('merged_options_data.csv')

# %%
df = pd.read_csv('..\data\merged_options_data.csv')

# %%
# Out:
#         Unnamed: 0 underlying_symbol        date  underlying_price  period  \
# 0                0              ^SPX  2016-01-04           2012.66      30
# 1                1              ^SPX  2016-01-04           2012.66      30
# 2                2              ^SPX  2016-01-04           2012.66      30
# 3                3              ^SPX  2016-01-04           2012.66      30
# 4                4              ^SPX  2016-01-04           2012.66      30
# 5                5              ^SPX  2016-01-04           2012.66      30
# 6                6              ^SPX  2016-01-04           2012.66      30
# 7                7              ^SPX  2016-01-04           2012.66      30
# 8                8              ^SPX  2016-01-04           2012.66      30
# 9                9              ^SPX  2016-01-04           2012.66      30
# 10              10              ^SPX  2016-01-04           2012.66      30
# 11              11              ^SPX  2016-01-04           2012.66      30
# 12              12              ^SPX  2016-01-04           2012.66      30
# 13              13              ^SPX  2016-01-04           2012.66      30
# 14              14              ^SPX  2016-01-04           2012.66      30
# 15              15              ^SPX  2016-01-04           2012.66      30
# 16              16              ^SPX  2016-01-04           2012.66      30
# 17              17              ^SPX  2016-01-04           2012.66      30
# 18              18              ^SPX  2016-01-04           2012.66      30
# 19              19              ^SPX  2016-01-04           2012.66      30
# 20              20              ^SPX  2016-01-04           2012.66      30
# 21              21              ^SPX  2016-01-04           2012.66      30
# 22              22              ^SPX  2016-01-04           2012.66      30
# 23              23              ^SPX  2016-01-04           2012.66      30
# 24              24              ^SPX  2016-01-04           2012.66      30
# 25              25              ^SPX  2016-01-04           2012.66      30
# 26              26              ^SPX  2016-01-04           2012.66      60
# 27              27              ^SPX  2016-01-04           2012.66      60
# 28              28              ^SPX  2016-01-04           2012.66      60
# 29              29              ^SPX  2016-01-04           2012.66      60
# ...            ...               ...         ...               ...     ...
# 117906         126              ^SPX  2019-01-02           2510.03     180
# 117907         127              ^SPX  2019-01-02           2510.03     180
# 117908         128              ^SPX  2019-01-02           2510.03     180
# 117909         129              ^SPX  2019-01-02           2510.03     180
# 117910         130              ^SPX  2019-01-02           2510.03     360
# 117911         131              ^SPX  2019-01-02           2510.03     360
# 117912         132              ^SPX  2019-01-02           2510.03     360
# 117913         133              ^SPX  2019-01-02           2510.03     360
# 117914         134              ^SPX  2019-01-02           2510.03     360
# 117915         135              ^SPX  2019-01-02           2510.03     360
# 117916         136              ^SPX  2019-01-02           2510.03     360
# 117917         137              ^SPX  2019-01-02           2510.03     360
# 117918         138              ^SPX  2019-01-02           2510.03     360
# 117919         139              ^SPX  2019-01-02           2510.03     360
# 117920         140              ^SPX  2019-01-02           2510.03     360
# 117921         141              ^SPX  2019-01-02           2510.03     360
# 117922         142              ^SPX  2019-01-02           2510.03     360
# 117923         143              ^SPX  2019-01-02           2510.03     360
# 117924         144              ^SPX  2019-01-02           2510.03     360
# 117925         145              ^SPX  2019-01-02           2510.03     360
# 117926         146              ^SPX  2019-01-02           2510.03     360
# 117927         147              ^SPX  2019-01-02           2510.03     360
# 117928         148              ^SPX  2019-01-02           2510.03     360
# 117929         149              ^SPX  2019-01-02           2510.03     360
# 117930         150              ^SPX  2019-01-02           2510.03     360
# 117931         151              ^SPX  2019-01-02           2510.03     360
# 117932         152              ^SPX  2019-01-02           2510.03     360
# 117933         153              ^SPX  2019-01-02           2510.03     360
# 117934         154              ^SPX  2019-01-02           2510.03     360
# 117935         155              ^SPX  2019-01-02           2510.03     360
#
#            strike option_type   delta  moneyness      iv
# 0        805.0640           P -0.0005       60.0  1.0140
# 1        905.6970           P -0.0008       55.0  0.9143
# 2       1006.3300           P -0.0011       50.0  0.8157
# 3       1106.9630           P -0.0016       45.0  0.7290
# 4       1207.5960           P -0.0025       40.0  0.6507
# 5       1308.2290           P -0.0035       35.0  0.5669
# 6       1408.8620           P -0.0053       30.0  0.4931
# 7       1509.4950           P -0.0089       25.0  0.4256
# 8       1610.1280           P -0.0169       20.0  0.3657
# 9       1710.7610           P -0.0368       15.0  0.3124
# 10      1811.3940           P -0.0912       10.0  0.2668
# 11      1912.0270           P -0.2333        5.0  0.2255
# 12      2012.6600           P -0.5396        0.0  0.1801
# 13      2012.6600           C  0.4613        0.0  0.1839
# 14      2113.2930           C  0.0849        5.0  0.1385
# 15      2213.9260           C  0.0064       10.0  0.1417
# 16      2314.5590           C  0.0018       15.0  0.1740
# 17      2415.1920           C  0.0014       20.0  0.2187
# 18      2515.8250           C  0.0000       25.0  0.0000
# 19      2616.4580           C  0.0000       30.0  0.0000
# 20      2717.0910           C  0.0000       35.0  0.0000
# 21      2817.7240           C  0.0000       40.0  0.0000
# 22      2918.3570           C  0.0000       45.0  0.0000
# 23      3018.9900           C  0.0000       50.0  0.0000
# 24      3119.6230           C  0.0000       55.0  0.0000
# 25      3220.2560           C  0.0000       60.0  0.0000
# 26       805.0640           P -0.0015       60.0  0.7975
# 27       905.6970           P -0.0019       55.0  0.7100
# 28      1006.3300           P -0.0026       50.0  0.6329
# 29      1106.9630           P -0.0033       45.0  0.5574
# ...           ...         ...     ...        ...     ...
# 117906  3639.5435           C  0.0033       45.0  0.1895
# 117907  3765.0450           C  0.0029       50.0  0.2034
# 117908  3890.5465           C  0.0027       55.0  0.2172
# 117909  4016.0480           C  0.0000       60.0  0.0000
# 117910  1004.0120           P -0.0065       60.0  0.4079
# 117911  1129.5135           P -0.0092       55.0  0.3740
# 117912  1255.0150           P -0.0137       50.0  0.3476
# 117913  1380.5165           P -0.0217       45.0  0.3290
# 117914  1506.0180           P -0.0334       40.0  0.3118
# 117915  1631.5195           P -0.0501       35.0  0.2956
# 117916  1757.0210           P -0.0743       30.0  0.2823
# 117917  1882.5225           P -0.1054       25.0  0.2672
# 117918  2008.0240           P -0.1474       20.0  0.2541
# 117919  2133.5255           P -0.2001       15.0  0.2400
# 117920  2259.0270           P -0.2659       10.0  0.2263
# 117921  2384.5285           P -0.3455        5.0  0.2125
# 117922  2510.0300           P -0.4387        0.0  0.1995
# 117923  2510.0300           C  0.5340        0.0  0.1859
# 117924  2635.5315           C  0.4234        5.0  0.1745
# 117925  2761.0330           C  0.3106       10.0  0.1641
# 117926  2886.5345           C  0.2082       15.0  0.1554
# 117927  3012.0360           C  0.1311       20.0  0.1508
# 117928  3137.5375           C  0.0805       25.0  0.1495
# 117929  3263.0390           C  0.0483       30.0  0.1497
# 117930  3388.5405           C  0.0298       35.0  0.1522
# 117931  3514.0420           C  0.0205       40.0  0.1577
# 117932  3639.5435           C  0.0000       45.0  0.0000
# 117933  3765.0450           C  0.0000       50.0  0.0000
# 117934  3890.5465           C  0.0000       55.0  0.0000
# 117935  4016.0480           C  0.0000       60.0  0.0000
#
# [117936 rows x 10 columns]
